# %%
# !git clone https://github.com/AUTOMATIC1111/stable-diffusion-webui
# Out:
# Cloning into 'stable-diffusion-webui'...
# remote: Enumerating objects: 34506, done.
# remote: Counting objects: 100% (116/116), done.
# remote: Compressing objects: 100% (86/86), done.
# remote: Total 34506 (delta 65), reused 56 (delta 28), pack-reused 34390 (from 1)
# Receiving objects: 100% (34506/34506), 35.20 MiB | 10.44 MiB/s, done.
# Resolving deltas: 100% (24119/24119), done.

# %%
# !git clone https://github.com/AUTOMATIC1111/stable-diffusion-webui
# Out:
# Cloning into 'stable-diffusion-webui'...
# remote: Enumerating objects: 34506, done.
# remote: Counting objects: 100% (116/116), done.
# remote: Compressing objects: 100% (86/86), done.
# remote: Total 34506 (delta 65), reused 56 (delta 28), pack-reused 34390 (from 1)
# Receiving objects: 100% (34506/34506), 35.22 MiB | 13.82 MiB/s, done.
# Resolving deltas: 100% (24134/24134), done.

# %%
# %cd /content/stable-diffusion-webui/models/Stable-diffusion
# !wget https://huggingface.co/Kotajiro/yayoi_mix/resolve/main/yayoi_mix_v20-fp16.safetensors
# Out:
# /content/stable-diffusion-webui/models/Stable-diffusion
# --2024-09-01 11:04:37--  https://huggingface.co/Kotajiro/yayoi_mix/resolve/main/yayoi_mix_v20-fp16.safetensors
# Resolving huggingface.co (huggingface.co)... 13.33.28.112, 13.33.28.94, 13.33.28.87, ...
# Connecting to huggingface.co (huggingface.co)|13.33.28.112|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
# %cd /content/stable-diffusion-webui
# !python launch.py --share --enable-insecure-extension-access
# Out:
# /content/stable-diffusion-webui
# Python 3.10.12 (main, Jul 29 2024, 16:56:48) [GCC 11.4.0]
# Version: v1.10.1
# Commit hash: 82a973c04367123ae98bd9abdf80d9eda9b910e2
# Launching Web UI with arguments: --share --enable-insecure-extension-access
# 2024-09-01 11:15:34.169231: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-09-01 11:15:34.190452: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-09-01 11:15:34.196966: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !rsync -av /content/stable-diffusion-webui/log/images /content/drive/MyDrive/ISAS/Meeting/Fujitsu/Stable-diffusion
# Out:
# sending incremental file list
# images/
# images/00000-60198027.png
# images/log.csv
#
# sent 313,061 bytes  received 58 bytes  626,238.00 bytes/sec
# total size is 312,784  speedup is 1.00
